# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/activities.csv')

# %%
df['type'].unique()
# Out:
# array(['WeightTraining', 'Yoga', 'Ride', 'Run', 'Swim', 'Workout',
#        'Surfing', 'Hike'], dtype=object)

# %%
df['start_date'] = pd.to_datetime(df.start_date, format='%Y-%m-%d %H:%M:%S%z')

# %%
df1=df[df['type'].isin(['Ride', 'Run', 'Swim'])]

# %%
df1=df1.replace('Ride','Training').replace('Run','Training').replace('Swim','Training')

# %%
df1
# Out:
#       resource_state                             name  distance  moving_time  \
# 2                  2    Sortie vélo dans l'après-midi   71417.1         9250
# 5                  2            Course à pied de nuit    8189.1         2450
# 10                 2  Course à pied dans l'après-midi    8021.1         2506
# 11                 2                 Natation le midi    1495.0         1659
# 14                 2          Course à pied en soirée   16005.6         4988
# ...              ...                              ...       ...          ...
# 1063               2     Décrassage du dimanche soir    13040.5         1572
# 1064               2                Montgiscard 2ème    20781.6         2842
# 1065               2          Sortie à vélo en soirée    4241.0          672
# 1066               2  Sortie à vélo dans l'après-midi   20370.2         2817
# 1067               2  Sortie à vélo dans l'après-midi   20939.3         2616
#
# ...

# %%
df1.set_index('start_date', inplace = True)

# %%
df1
# Out:
#                            resource_state                             name  \
# start_date
# 2022-06-26 12:02:10+00:00               2    Sortie vélo dans l'après-midi
# 2022-06-25 19:18:59+00:00               2            Course à pied de nuit
# 2022-06-23 11:08:45+00:00               2  Course à pied dans l'après-midi
# 2022-06-23 10:30:55+00:00               2                 Natation le midi
# 2022-06-22 18:04:27+00:00               2          Course à pied en soirée
# ...                                   ...                              ...
# 2019-07-14 18:25:17+00:00               2     Décrassage du dimanche soir
# 2019-06-23 13:35:57+00:00               2                Montgiscard 2ème
# 2019-05-09 17:16:20+00:00               2          Sortie à vélo en soirée
# 2019-05-08 15:17:53+00:00               2  Sortie à vélo dans l'après-midi
# 2019-05-08 14:26:32+00:00               2  Sortie à vélo dans l'après-midi
#
# ...

# %%
import calplot
pl1 = calplot.calplot(data = df1['moving_time'],how = 'sum', cmap = 'YlGn', figsize = (16, 8), colorbar=False, suptitle = "Sport by Month and Year")
# Out:
# C:\Users\T526988\Anaconda3\lib\site-packages\calplot\calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# C:\Users\T526988\Anaconda3\lib\site-packages\calplot\calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# C:\Users\T526988\Anaconda3\lib\site-packages\calplot\calplot.py:193: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   ax.set_xticks([by_day.loc[pd.Timestamp(
# ...

# %%
df1
# Out:
#                            resource_state                             name  \
# start_date
# 2022-06-27 03:55:23+00:00               2   Séance de musculation le matin
# 2022-06-27 03:50:58+00:00               2                    Yoga le matin
# 2022-06-26 12:02:10+00:00               2    Sortie vélo dans l'après-midi
# 2022-06-26 05:31:30+00:00               2   Séance de musculation le matin
# 2022-06-26 05:23:52+00:00               2                    Yoga le matin
# ...                                   ...                              ...
# 2019-07-14 18:25:17+00:00               2     Décrassage du dimanche soir
# 2019-06-23 13:35:57+00:00               2                Montgiscard 2ème
# 2019-05-09 17:16:20+00:00               2          Sortie à vélo en soirée
# 2019-05-08 15:17:53+00:00               2  Sortie à vélo dans l'après-midi
# 2019-05-08 14:26:32+00:00               2  Sortie à vélo dans l'après-midi
#
# ...

# %%
df2=pd.read_csv('./data/activities_d.csv')

# %%
df2=df2.replace('Ride','Training').replace('Run','Training').replace('Swim','Training')

# %%
df2['start_date_local_'] =pd.to_datetime(df2.start_date_local_, format='%Y-%m-%d %H:%M:%S%z', utc=True).dt.strftime('%Y-%m-%d')

df2['start_date_local_'] =pd.to_datetime(df2.start_date_local_, format='%Y-%m-%d', utc=True)

# %%
df2
# Out:
#                type_         start_date_local_  distance_sum  distance_mean  \
# 0     WeightTraining 2022-06-27 00:00:00+00:00           0.0            0.0
# 1               Yoga 2022-06-27 00:00:00+00:00           0.0            0.0
# 2           Training 2022-06-26 00:00:00+00:00       71417.1        71417.1
# 3     WeightTraining 2022-06-26 00:00:00+00:00           0.0            0.0
# 4               Yoga 2022-06-26 00:00:00+00:00           0.0            0.0
# ...              ...                       ...           ...            ...
# 1063        Training 2019-07-14 00:00:00+00:00       13040.5        13040.5
# 1064        Training 2019-06-23 00:00:00+00:00       20781.6        20781.6
# 1065        Training 2019-05-09 00:00:00+00:00        4241.0         4241.0
# 1066        Training 2019-05-08 00:00:00+00:00       20370.2        20370.2
# 1067        Training 2019-05-08 00:00:00+00:00       20939.3        20939.3
#
# ...

# %%
import datetime
currentDate = datetime.date.today()
a = datetime.date(currentDate.year, currentDate.month, 1)

# %%
a = pd.to_datetime(a, format='%Y-%m-%d', errors='ignore',utc=True)

# %%
a
# Out:
# Timestamp('2022-06-01 00:00:00+0000', tz='UTC')

# %%
from datetime import date, datetime, time
d=datetime.today() - timedelta(days=15)
d=pd.to_datetime(d, format='%Y-%m-%d', errors='ignore',utc=True)

# %%
d
# Out:
# Timestamp('2022-06-13 17:22:40.277443+0000', tz='UTC')

# %%
df2=df2.loc[df2['start_date_local_'] > d]

# %%
df2
# Out:
#              type_         start_date_local_  distance_sum  distance_mean  \
# 0   WeightTraining 2022-06-27 00:00:00+00:00           0.0            0.0
# 1             Yoga 2022-06-27 00:00:00+00:00           0.0            0.0
# 2         Training 2022-06-26 00:00:00+00:00       71417.1        71417.1
# 3   WeightTraining 2022-06-26 00:00:00+00:00           0.0            0.0
# 4             Yoga 2022-06-26 00:00:00+00:00           0.0            0.0
# 5         Training 2022-06-25 00:00:00+00:00        8189.1         8189.1
# 6   WeightTraining 2022-06-25 00:00:00+00:00           0.0            0.0
# 7             Yoga 2022-06-25 00:00:00+00:00           0.0            0.0
# 8   WeightTraining 2022-06-24 00:00:00+00:00           0.0            0.0
# 9             Yoga 2022-06-24 00:00:00+00:00           0.0            0.0
# 10        Training 2022-06-23 00:00:00+00:00        8021.1         8021.1
# 11        Training 2022-06-23 00:00:00+00:00        1495.0         1495.0
# ...

# %%
#df2.set_index('start_date_local_', inplace = True)

# %%
#Importing the seaborn library along with other dependencies
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime

# %%
pivoted_data = pd.pivot_table(df2[['start_date_local_','moving_time_sum','type_']],
                              values='moving_time_sum',index=['type_'] , columns=['start_date_local_'])

# %%
pivoted_data
# Out:
# start_date_local_  2022-06-14 00:00:00+00:00  2022-06-15 00:00:00+00:00  \
# type_
# Training                         3018.333333                     1963.6
# WeightTraining                           NaN                        NaN
# Yoga                                     NaN                        NaN
#
# start_date_local_  2022-06-16 00:00:00+00:00  2022-06-18 00:00:00+00:00  \
# type_
# Training                              2739.0                     2102.5
# WeightTraining                           NaN                        NaN
# Yoga                                     NaN                        NaN
#
# start_date_local_  2022-06-20 00:00:00+00:00  2022-06-21 00:00:00+00:00  \
# type_
# Training                              2613.5                     1902.0
# WeightTraining                           NaN                        NaN
# Yoga                                     NaN                        NaN
#
# ...

# %%
#pivoted_data[pivoted_data>0]=1

# %%
pivoted_data
# Out:
# start_date_local_  2022-06-14 00:00:00+00:00  2022-06-15 00:00:00+00:00  \
# type_
# Training                         3018.333333                     1963.6
# WeightTraining                           NaN                        NaN
# Yoga                                     NaN                        NaN
#
# start_date_local_  2022-06-16 00:00:00+00:00  2022-06-18 00:00:00+00:00  \
# type_
# Training                              2739.0                     2102.5
# WeightTraining                           NaN                        NaN
# Yoga                                     NaN                        NaN
#
# start_date_local_  2022-06-20 00:00:00+00:00  2022-06-21 00:00:00+00:00  \
# type_
# Training                              2613.5                     1902.0
# WeightTraining                           NaN                        NaN
# Yoga                                     NaN                        NaN
#
# ...

# %%
plt.figure(figsize = (16,6))
sns.heatmap(pivoted_data, linewidths=5, cmap='Greens',linecolor='white', square=True,cbar=False,vmin=0,vmax=1)
# Out:
# <AxesSubplot:xlabel='start_date_local_', ylabel='type_'>
